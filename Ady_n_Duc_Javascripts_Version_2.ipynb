# %% [markdown]
# <a href="https://colab.research.google.com/github/duchaba/public_sandbox/blob/main/Ady_n_Duc_Javascripts_Version_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.0 Introduction - Version 2.0

# %% [markdown]
# - When I first learn to use the Jupyter notebook, I thought it was exclusively for Python, but I was wrong. There is an open-source community that uses Jupyter’s notebook for every conceivable language.
#
# - I primarily use a Jupyter’s notebook for teaching and exploring. Afterward I refactor the code into a reusable library. I use Atom’s IDE.
#
# - Enough talk, let’s hack!

# %% [markdown]
# > <h2><center>Ady, Welcome to Jupyter Notebook Sandbox session, Version 2.0.</center></h2>
#
# ---
#
# > <h2><i>If you have not done so, save the notebook to your Goggle Drive, cloud server or local drive.</i></h2>

# %% [markdown]
# # 2.0 SetUp

# %% [markdown]
# - Similar to version 1.0, but instead of using "ijavascript" kernal for NodeJS, we use "[PixieDust](https://pixiedust.github.io/pixiedust/)."
#
# The primary advantages in using PixelDust is that it run both Python and NodeJS, so that we can use "ipyWidgets" to create HTML widgets, e.g. tab, buttons, sliders, flex-box, etc.

# %%
# %%capture out_1
# install or upgrade the packages
# restart the kernel to pick up the latest version
# !pip install pixiedust --upgrade
# !pip install pixiedust_node --upgrade

# %%
# import pixiedust
import pixiedust_node
# Out:
# Pixiedust database opened successfully
# Table VERSION_TRACKER created successfully
# Table METRICS_TRACKER created successfully
#
# Share anonymous install statistics? (opt-out instructions)
#
# PixieDust will record metadata on its environment the next time the package is installed or updated. The data is anonymized and aggregated to help plan for future releases, and records only the following values:
#
# {
#    "data_sent": currentDate,
#    "runtime": "python",
#    "application_version": currentPixiedustVersion,
#    "space_id": nonIdentifyingUniqueId,
#    "config": {
#        "repository_id": "https://github.com/ibm-watson-data-lab/pixiedust",
#        "target_runtimes": ["Data Science Experience"],
#        "event_id": "web",
#        "event_organizer": "dev-journeys"
#    }
# }
# You can opt out by calling pixiedust.optOut() in a new cell.
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
# ...

# %% [markdown]
# ><h2><center>Javascripts (NodeJS) code start with %%node</center></h2>

# %%
# %%node
# console.log("I am Node Javascripts.");

# %%
# check out what modules available to use
# !jupyter --version
# Out:
# pixiedust_node 0.2.5 started. Cells starting '%%node' may contain Node.js code.
# I am Node Javascripts.
# jupyter core     : 4.5.0
# jupyter-notebook : 5.2.2
# qtconsole        : 4.5.2
# ipython          : 5.5.0
# ipykernel        : 4.10.1
# jupyter client   : 5.3.1
# jupyter lab      : not installed
# nbconvert        : 5.5.0
# ipywidgets       : 7.5.0
# nbformat         : 4.4.0
# traitlets        : 4.3.2

# %%
# %lsmagic

# %% [markdown]
# # 3.0 Share-data dictionary and App class

# %% [markdown]
# - Start with a "Shareable" global variable (a dictionary) where you can pass data between the native Python and the NodeJS/Javascript.
#
# - The reason for sharable data is we will use NodeJS/Javascript for the logic and the "widgets" is from "ipywidgets" package.

# %%
# %%node
# global.ShareData = {"version": "0.2.0"};

# %% [markdown]
# - As a good little programmer, we start by creating an object or class in Javascripts.

# %%
# %%node
# class App {
#   constructor() {
#     ShareData["css"] = {"txt": ' style="padding: 1rem; font-size:1.3rem;font-family:cursive;" '};
#   }
#   //
#   print(msg) {
#     html('<div ' + ShareData["css"]["txt"] + '>' + msg + '</div>');
#   }
# }

# %%
# %%node
# kid = new App()

# %%
# %%node
# // test it
# kid.print("Hello world!");
# Out:
# <div  style="padding: 1rem; font-size:1.3rem;font-family:cursive;" >Hello world!</div>

# %% [markdown]
# - You can update the css by update the shareable object (dictionary), and add new method as needed.

# %%
# %%node
# ShareData["css"]["card"] = ' style="padding: 2rem; border: 1px solid #333344;border-radius: 5px;background-color: #20c997;color: #ffffff;font-family: serif;font-size:5rem;text-align: center; display: inline-block;box-shadow: 3px 3px 8px rgba(0,0,0,0.2);"';
# App.prototype.printCard = function (msg) {
#   html('<div ' + ShareData["css"]["card"] + '>' + msg + '</div>');
# };
# Out:
# ... ...

# %%
# %%node
# kid.printCard("a");
# Out:
# <div  style="padding: 2rem; border: 1px solid #333344;border-radius: 5px;background-color: #20c997;color: #ffffff;font-family: serif;font-size:5rem;text-align: center; display: inline-block;box-shadow: 3px 3px 8px rgba(0,0,0,0.2);">a</div>

# %%
# %%node
# kid.printCard("B");
# Out:
# <div  style="padding: 2rem; border: 1px solid #333344;border-radius: 5px;background-color: #20c997;color: #ffffff;font-family: serif;font-size:5rem;text-align: center; display: inline-block;box-shadow: 3px 3px 8px rgba(0,0,0,0.2);">B</div>

# %%
# %%node
# html('<div style="font-family:cursive;}">Hello me</div>');
# Out:
# <div style="{font-family:cursive;}">Hello me</div>

# %%
# %%node
# console.log(ShareData);
# Out:
# { date: 'yesterday', cat: 'yellow', x: [ 1, 2, 3, 4, 5 ] }

# %%
print (ShareData)
# Out:
# {'date': 'yesterday', 'cat': 'yellow', 'x': [1, 2, 3, 4, 5]}

# %%
# %%node
# ShareData["cat"] = "cat";
# ShareData["date"] = "yesterday";

# %%
ShareData["cat"] = "yellow"
ShareData["x"] = [1,2,3,4,5]

# %%
# %%node
# ShareData.cat = "green";

# %%
# %%node
# class App {
#   constructor(author) {
#     ShareData["author"] = author;
#   }
#   //
#   sayHello() {
#     console.log("Hello from " + ShareData["author"] );
#   }
# }
# Out:
# ... ..... ..... ... ... ..... ..... ...

# %%
# %%node
# var sam = new App("Sammy");

# %%
# %%node
# sam.sayHello()
# Out:
# Hello from Jenny

# %%
print(ShareData)
# Out:
# {'date': 'yesterday', 'cat': 'yellow', 'x': [1, 2, 3, 4, 5], 'author': 'Sammy'}

# %%
ShareData["author"] = "Jenny"

# %%
# %%node
# var a = "cat"

# %%
print(a)
# Out:
# cat

# %%
# %%node
# var x = {"cat": 99};

# %%
print(x)
# Out:
# {'cat': 987, 'dog': 'yello', 'pig': 'green'}

# %%
# %%node
# console.log(x)
# Out:
# { cat: 987, dog: 'yello', pig: 'green' }

# %%
# %%node
# x.cat = 123;

# %%
x["cat"] = 987

# %%
x["dog"] = "yello"

# %%
# %%node
# x["pig"] = "green"

# %%
ShareableData = {"name": "sammy", "age": 12}

# %%
# %%node
# console.log(ShareableData)
# Out:
# { name: 'Every', age: 12, color: 'blue green', tv: [ 1, 2, 3 ] }

# %%
print(ShareableData)
# Out:
# {'name': 'Every', 'age': 12, 'color': 'blue green', 'tv': [1, 2, 3]}

# %%
# %%node
# ShareableData["name"] = "Jenny";
# ShareableData["color"] = "pink";

# %%
ShareableData["name"] = "Every";
ShareableData["color"] = "blue green"
ShareableData["tv"] = [1, 2, 3]

# %%
# %%node
# global.c = {"name": "candy"};

# %%
print(c)
# Out:
# {'name': 'Ted', 'color': 'pink', 'xz': [1, 2, 3, 4, 4, 5, 5, 5]}

# %%
# %%node
# console.log(c);
# Out:
# {
# name: 'Ted',
# color: 'pink',
# xz: [
# 1, 2, 3, 4,
# 4, 5, 5, 5
# ]
# }

# %%
c["color"] = "pink"
c["name"] = "sandy"

# %%
# %%node
# c["name"] = "Ted";
# c["xz"] = [1,2,3,4,4,5,5,5];

# %%
# %%node
# class App {
#   constructor(author) {
#     _Data.author = author;
#     this.date = new Date();
#   }
#   //
#   sayHello() {
#     console.log("Hello from " + _Data.author );
#   }
# }

# %%
# %%node
# // create Sammy
# var sammy = new App("Sammy");

# %%
# %%node
# sammy.sayHello();
# Out:
# Hello from Sammy

# %%
_Data["cat"] = "Hello pig."

# %%
print(_Data)
# Out:
# {'cat': 'Hello pig.', 'dog': 6, 'author': 'Sammy', 'pig': 'Hello pig.'}

# %%
# %%node
# console.log(_Data)
# Out:
# { cat: 'cat', dog: 6, author: 'Sammy' }

# %%
# %%node
# _Data.cow = "Hi cow";

# %%
# %%node
# console.log(_Data)
# Out:
# { cat: 'cat', dog: 6, author: 'Sammy', cow: 'Hi cow' }

# %%
_Data["cat"] =  "big yellow cat"

# %%
# %%node
# print(process.env)
# Out:
# {"NO_GCE_CHECK": "True", "GCS_READ_CACHE_BLOCK_SIZE_MB": "16", "CLOUDSDK_CONFIG": "/content/.config", "__EGL_VENDOR_LIBRARY_DIRS": "/usr/lib64-nvidia:/usr/share/glvnd/egl_vendor.d/", "CUDA_VERSION": "10.1.243", "PATH": "/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin", "HOME": "/root", "LD_LIBRARY_PATH": "/usr/lib64-nvidia", "LANG": "en_US.UTF-8", "SHELL": "/bin/bash", "LIBRARY_PATH": "/usr/local/cuda/lib64/stubs", "CUDA_PKG_VERSION": "10-1=10.1.243-1", "SHLVL": "1", "GCE_METADATA_TIMEOUT": "0", "NCCL_VERSION": "2.7.8", "NVIDIA_VISIBLE_DEVICES": "all", "TF_FORCE_GPU_ALLOW_GROWTH": "true", "DEBIAN_FRONTEND": "noninteractive", "CUDNN_VERSION": "7.6.5.32", "LAST_FORCED_REBUILD": "20201027", "JPY_PARENT_PID": "25", "PYTHONPATH": "/env/python", "DATALAB_SETTINGS_OVERRIDES": "{\"kernelManagerProxyPort\":6000,\"kernelManagerProxyHost\":\"172.28.0.3\",\"jupyterArgs\":[\"--ip=\\\"172.28
# ...

# %%
# %%node
# store(sammy, 'sam');
# Out:
# !!! Warning: store is now deprecated - Node.js global variables are automatically propagated to Python !!!
# {"_pixiedust":true,"type":"store","data":{"name":"Sammy","age":4,"date":"2020-10-30T09:01:55.934Z"},"variable":"sam"}

# %%
print(sam.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-eae65eceb523> in <module>()
# ----> 1 print(sam.name)
#
# NameError: name 'sam' is not defined

# %%
print (process.env)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5c6eeb7a564e> in <module>()
# ----> 1 print (process.env)
#
# NameError: name 'process' is not defined

# %%
# %%node
# var wave = [];
# for (var i = 0; i < 1000; i++) {
#     var x = 2*Math.PI * i/ 360;
#     var obj = {
#       x: x,
#       i: i,
#       sin: Math.sin(x),
#       cos: Math.cos(x),
#       tan: Math.tan(x)
#     };
#     wave.push(obj);
# }

# %%
# %%node
# store(wave, "w")

# %%
print(w.count())
# Out:
# x      1000
# i      1000
# sin    1000
# cos    1000
# tan    1000
# dtype: int64

# %% [markdown]
# - Access Sammy from Python

# %%
# %%node
# console.log(sammy.date)
# Out:
# 2020-10-30T07:24:52.079Z

# %%
print(sam.date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7be10fd8bcb4> in <module>()
# ----> 1 print(sam.date)
#
# NameError: name 'sam' is not defined

# %%
# %%node
# // add new method to Person (and sammy)
# Person.prototype.print = function (text) {
#   var css = ' style="font-family:serif;font-size:1.3rem;padding:0.7rem;color:#444455;font-family:cursive;" ';
#   var h = '<div ' + css + '>' + text + '</div>';
#   html(h)
# };
# Out:
# ... ... ... ...

# %%
# %%node
# sammy.print("Hello");
# Out:
# <div  style="font-family:serif;font-size:1.3rem;padding:0.7rem;color:#444455;font-family:cursive;" >Hello</div>

# %%
# %%node
# html('<link href="https://fonts.googleapis.com/css?family=Bad+Script&amp;display=swap" rel="stylesheet">');
# Out:
# <link href="https://fonts.googleapis.com/css?family=Bad+Script&amp;display=swap" rel="stylesheet">

# %%
# %%node
# var ix = "happy";
# print(ix);
# Out:
# "happy"

# %%
print(ix)
# Out:
# happy

# %%
ix = "have a nice day"
print(ix)
# Out:
# have a nice day

# %%
# %%node
# console.log(ix);
# Out:
# have a nice day

# %%
# %%javascript
# prompt('hello python');

# %%
# %connect_info
# Out:
# {
#   "shell_port": 50829,
#   "iopub_port": 35293,
#   "stdin_port": 34553,
#   "control_port": 53805,
#   "hb_port": 36385,
#   "ip": "127.0.0.1",
#   "key": "",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-46981981-28d2-4ee5-b31a-66dd3d612ca3.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
# %colors LightBG

# %% [markdown]
# # 4.0 Hack your notebook page

# %% [markdown]
# - There are many addons to Jupyter Notebook, but unless you host your Jupyter Notebook or use the cloud server that allows you to use them, you can’t use it. Unfortunately, my choice of Google Collab does not support it. https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/
#
# - However, strip away all the fancy terminologies, Jupyter Notebook is a “web page.” So, we hacked it.
#
# - Open the webpage “[dev] inspect” via right-click or “cntr-shift-i,” and hack it.

# %%
// # OPTIONAL
// # For Google Colab, (1) Open the "concole", e.g. right-click and inspect, (2) Copy the below scripts (from line #10 to #17) and run it.
// #
// # If you know how to hack Google Colab Jupyter notebook and run "javascripts" as-is below, 
// #i.e., without the need for opening up the console, please share it with me.
// #
// # The Javascript is to highlight the code cells' input and output and the code-cells you have executed.
// #
// %%js
var head = document.head || document.getElementsByTagName("head")[0];
var style = document.createElement("style");
var css = ".inputarea.code{border-left: 4px solid #20c997;}.cell.focused .inputarea.code{border-left: 4px solid #d63384;}.cell .output{border-left: 4px solid #ffc107;}";
css = css + ":root { --colab-fresh-execution-count-color: #d63384;}";
css = css + ".markdown blockquote {border-left: 10px solid #fd7e14 !important;border-radius: 10px 0 0 10px;padding: 1em 1em 1em 1em;border-bottom: 1px solid #343845}"
css = css + " h1,h2,h3,h4,h5 {font-family:serif !important;}"
css = css + "h1{color:#e83e8c !important;;} h2{color:#20c997 !important;;} h3{color:#fd7e14 !important;;} h4{color:#6610f2 !important;}"
head.appendChild(style);
style.type = "text/css";
style.appendChild(document.createTextNode(css));

# %% [markdown]
# ## 4.1 Changing Theme and "Magic" Commands

# %% [markdown]
# 1. Change the "theme" by click on "Tools -> Settings -> Select dark theme."

# %% [markdown]
# ## 4.2 Import External CSS

# %% [markdown]
# - Upload the "app.css" file first

# %%
$$.async();

var cell1 = {
    $$: $$,
    console: console,
};

setTimeout(function() {
    cell1.console.log("Hello, world!");
    cell1.$$.sendResult("Bye!");
}, 1000);
# Out:
# Hello, world!
# 'Bye!'

# %%
$$.mime({
    "text/html": "<div style='background-color:olive;width:50px;height:50px'></div>",
});
# Out:
# <div style='background-color:olive;width:50px;height:50px'></div>

# %%
$$.mime({
    "text/css": ".btn{background-color:pink;width:150px;height:50px;}",
});

# %%
var h = '<div class="btn">Hello</div>';
$$.html(h);
# Out:
# <div class="btn">Hello</div>

# %%
var head = decodeURI("html")

# %%
var jsdom = require('jsdom');
var THREE = require('three');

var {CanvasRenderer} = require('three-canvas-renderer');

var dom = new jsdom.JSDOM(`
<!doctype html>
<html>
  <head>
    <title>Jupyter-FourD</title>
  </head>
  <body>
    <canvas id="canvas">
  </body>
</html>
`);

var width = 500;
var height = 300;

var canvas = dom.window.document.querySelector('#canvas');


$d = $$.display('jupyter-fourd');

var scene = new THREE.Scene();
var camera = new THREE.PerspectiveCamera(75, width/height, 0.1, 1000 );

var renderer = new THREE.CanvasRenderer({canvas: canvas});
renderer.setSize(width, height);

var geometry = new THREE.BoxGeometry( 1, 1, 1 );
var material = new THREE.MeshBasicMaterial( { color: 0x00ff00 } );
var cube = new THREE.Mesh( geometry, material );
scene.add( cube );

camera.position.z = 5;

var animate = function () {
    cube.rotation.x += 0.1;
    cube.rotation.y += 0.1;

    renderer.render( scene, camera );
    
    $d.png(canvas.toDataURL().slice(22));
};

var i = setInterval(animate, 160);
# Out:
# THREE.CanvasRenderer 122
# Error: Not implemented: HTMLCanvasElement.prototype.getContext (without installing the canvas npm package)
#     at module.exports (/content/node_modules/jsdom/lib/jsdom/browser/not-implemented.js:9:17)
#     at HTMLCanvasElementImpl.getContext (/content/node_modules/jsdom/lib/jsdom/living/nodes/HTMLCanvasElement-impl.js:42:5)
#     at HTMLCanvasElement.getContext (/content/node_modules/jsdom/lib/jsdom/living/generated/HTMLCanvasElement.js:130:58)
#     at new THREE.CanvasRenderer (/content/node_modules/three-canvas-renderer/index.js:994:21)
#     at evalmachine.<anonymous>:29:16
#     at Script.runInThisContext (vm.js:116:20)
#     at Object.runInThisContext (vm.js:306:38)
#     at run ([eval]:1054:15)
#     at onRunRequest ([eval]:888:18)
#     at onMessage ([eval]:848:13) undefined
# /content/node_modules/three-canvas-renderer/index.js:1057
# 	if ( _context.setLineDash === undefined ) {
# 	              ^
#
# ...

# %%
console.log("hello")
# Out:
# hello

# %%
child_process.execSync("npm install jsdom");
# Out:
# npm WARN deprecated request@2.88.2: request has been deprecated, see https://github.com/request/request/issues/3142
# npm WARN deprecated request-promise-native@1.0.9: request-promise-native has been deprecated because it extends the now deprecated request package, see https://github.com/request/request/issues/3142
# npm WARN deprecated har-validator@5.1.5: this library is no longer supported
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
# <Buffer 2b 20 6a 73 64 6f 6d 40 31 36 2e 34 2e 30 0a 61 64 64 65 64 20 39 37 20 70 61 63 6b 61 67 65 73 20 66 72 6f 6d 20 31 33 30 20 63 6f 6e 74 72 69 62 75 ... 130 more bytes>

# %%
child_process.execSync("npm install dstools");
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
# <Buffer 0a 3e 20 63 6f 72 65 2d 6a 73 2d 70 75 72 65 40 33 2e 36 2e 35 20 70 6f 73 74 69 6e 73 74 61 6c 6c 20 2f 63 6f 6e 74 65 6e 74 2f 6e 6f 64 65 5f 6d 6f ... 787 more bytes>

# %%
child_process.execSync("npm install three");
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
# <Buffer 2b 20 74 68 72 65 65 40 30 2e 31 32 32 2e 30 0a 61 64 64 65 64 20 31 20 70 61 63 6b 61 67 65 20 66 72 6f 6d 20 31 20 63 6f 6e 74 72 69 62 75 74 6f 72 ... 209 more bytes>

# %%
child_process.execSync("npm install three-canvas-renderer");
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
# <Buffer 2b 20 74 68 72 65 65 2d 63 61 6e 76 61 73 2d 72 65 6e 64 65 72 65 72 40 32 2e 30 2e 30 0a 61 64 64 65 64 20 31 20 70 61 63 6b 61 67 65 20 66 72 6f 6d ... 223 more bytes>

# %%
child_process.execSync("npm install canvas");
# Out:
# node-pre-gyp WARN Using request for node-pre-gyp https download
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
# <Buffer 0a 3e 20 63 61 6e 76 61 73 40 32 2e 36 2e 31 20 69 6e 73 74 61 6c 6c 20 2f 63 6f 6e 74 65 6e 74 2f 6e 6f 64 65 5f 6d 6f 64 75 6c 65 73 2f 63 61 6e 76 ... 408 more bytes>

# %% [markdown]
# # 5.0 A Few Good Reference Notebooks and Websites

# %% [markdown]
# 1. Google Colab Quick Guide, https://colab.research.google.com/notebooks/basic_features_overview.ipynb
#
# 2. Google Colab Form, https://colab.research.google.com/notebooks/forms.ipynb
#
# 3. Jupyter notebook magic commands, https://nbviewer.jupyter.org/github/ipython/ipython/blob/1.x/examples/notebooks/Cell%20Magics.ipynb
#
# ---
#
# 1. Popular Jupyter Notebook Cloud Services, https://www.dataschool.io/cloud-services-for-jupyter-notebook/
#
# 1. iJavascript notebook home page, http://n-riesco.github.io/ijavascript/
#
# 1. Jupyter notebook website include "how to install on your labtop", https://jupyter.org/index.html
#
# 2. Unofficial Jupyter Notebook Extensions, https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/

# %% [markdown]
# # 6.0 It is Rum and Coke Time. :-)
